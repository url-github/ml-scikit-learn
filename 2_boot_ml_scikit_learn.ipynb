# %% [markdown]
# ![2021-08-22 20_55_46-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %%
import pandas as pd
df = pd.DataFrame(data={'investments': ['100_000_000', '100_000', '30_000_000', '100_500_000']})
df.head()
# Out:
#    investments
# 0  100_000_000
# 1      100_000
# 2   30_000_000
# 3  100_500_000

# %%
df['investments'] = df['investments'].str.replace('_', '').astype(int)
df.head()
# Out:
#    investments
# 0    100000000
# 1       100000
# 2     30000000
# 3    100500000

# %% [markdown]
# ![2021-08-22 21_01_49-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html

# %%
from sklearn.datasets import load_iris
data = load_iris()
data.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names', 'filename'])

# %% [markdown]
# ![2021-08-22 21_19_35-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
data['feature_names']
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
data['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ![2021-08-22 21_25_32-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %%
from sklearn.datasets import load_iris
 
data_raw = load_iris()
data = data_raw['data']
target = data_raw['target']
print(data.shape)
print(target.shape)
# Out:
# (150, 4)
# (150,)

# %% [markdown]
# ![2021-08-22 21_32_24-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

data_raw = load_iris()
data = data_raw['data']
target = data_raw['target']

# %%
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3)
print(f'data_train shape: {data_train.shape}')
print(f'target_train shape: {target_train.shape}')
print(f'data_test shape: {data_test.shape}')
print(f'target_test shape: {target_test.shape}')
# Out:
# data_train shape: (105, 4)
# target_train shape: (105,)
# data_test shape: (45, 4)
# target_test shape: (45,)

# %% [markdown]
# ![2021-08-23 18_36_25-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

data_raw = load_iris()
data = data_raw['data']
target = data_raw['target']
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3, random_state=20)

# %%
model = LogisticRegression(max_iter=100)
model.fit(data_train, target_train)
accuracy = model.score(data_test, target_test)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# Accuracy: 0.9333

# %% [markdown]
# ![2021-08-23 18_48_43-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

data_raw = load_iris()
data = data_raw['data']
target = data_raw['target']
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3, random_state=20)

model = LogisticRegression(max_iter=1000)
model.fit(data_train, target_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
target_pred = model.predict(data_test)
print(target_pred)
# Out:
# [0 1 1 2 1 1 2 0 2 0 2 1 1 0 0 2 0 1 2 1 1 2 2 0 1 1 1 0 2 1 1 1 0 0 0 1 1
#  0 1 2 1 2 0 1 1]

# %% [markdown]
# ![2021-08-23 19_21_37-Machine Learning Bootcamp w języku Python cz.III - Ćwiczenia _ Udemy.png](data:image/png;base64,...)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.confusion_matrix.html

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

data_raw = load_iris()
data = data_raw['data']
target = data_raw['target']
data_train, data_test, target_train, target_test = train_test_split(data, target, test_size=0.3, random_state=20)

model = LogisticRegression(max_iter=1000)
model.fit(data_train, target_train)

target_pred = model.predict(data_test)

# %%
cm = confusion_matrix(target_test, target_pred)
print(cm)
# Out:
# [[13  0  0]
#  [ 0 18  0]
#  [ 0  3 11]]
